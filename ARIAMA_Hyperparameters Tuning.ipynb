# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import GridSearchCV
from sklearn.base import BaseEstimator, RegressorMixin

# %%
# Read the dataset from the CSV file called 'Co2_Data.csv' and store it in a DataFrame called df
df = pd.read_csv('CO2_Data.csv')
df
# Out:
#         CO2  Year&Month  Year  Month
# 0    333.13     1974.38  1974      5
# 1    332.09     1974.46  1974      6
# 2    331.10     1974.54  1974      7
# 3    329.14     1974.63  1974      8
# 4    327.36     1974.71  1974      9
# ..      ...         ...   ...    ...
# 156  351.71     1987.38  1987      5
# 157  350.94     1987.46  1987      6
# 158  349.10     1987.54  1987      7
# 159  346.77     1987.63  1987      8
# 160  345.73     1987.71  1987      9
#
# [161 rows x 4 columns]

# %%
df.set_index(['Year&Month', 'Year', 'Month'], inplace=True)
co2_data = df['CO2']

# %%
# Define the sliding window size
window_size = 2  # Adjust as needed

# Apply the sliding window approach
predictions = []
actual_values = []

for i in range(len(co2_data) - window_size + 1):
    train_window = co2_data[i:i+window_size]
    model = ARIMA(train_window, order=(1, 0, 0))  # Adjust the order as needed
    model_fit = model.fit()
    forecast = model_fit.forecast(steps=1)
    predicted_value = forecast.iloc[0]  # Access the forecasted value
    
    predictions.append(predicted_value)
    actual_values.append(co2_data.iloc[i+window_size-1])
    
    if i+window_size < len(co2_data):
        train_window = train_window.append(pd.Series(co2_data.iloc[i+window_size], index=[co2_data.index[i+window_size]]))
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
# GridSearchCV for parameter tuning
parameters = {
    'order': [(1, 0, 0), (0, 1, 0), (0, 0, 1)]
}

class ARIMAWrapped(BaseEstimator, RegressorMixin):
    def __init__(self, order):
        self.order = order
        self.model = None

    def fit(self, X, y=None):
        self.model = ARIMA(X, order=self.order)
        self.model_fit = self.model.fit()
        return self

    def predict(self, X):
        # Forecast using the ARIMA model
        forecast = self.model_fit.forecast(steps=len(X))
        return forecast

# %%
# Define features (X) and target variable (y)
X = co2_data.values[:-1]  # All except the last value
y = co2_data.values[1:]   # All except the first value

# %%
# Initialize the ARIMA model
model = ARIMAWrapped(order=(0, 0, 0))
grid_search = GridSearchCV(model, parameters, scoring='neg_mean_squared_error')
grid_search.fit(X, y)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...

# %%
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'order': (0, 0, 1)}

# %%
# Update the model with the best parameters
best_model = ARIMAWrapped(order=best_params['order'])
best_model.fit(X, y)
# Out:
# ARIMAWrapped(order=(0, 0, 1))

# %%
# Generate predictions using the best model
best_predictions = []

for i in range(len(co2_data)):
    if i < window_size:
        best_predictions.append(np.mean(co2_data[:i]))
    else:
        features = co2_data.iloc[i - window_size:i].values
        prediction = best_model.predict(features.reshape(1, -1))[0]
        best_predictions.append(prediction)

print(len(best_predictions))
# Out:
# 161

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Split data into training and test sets
train_size = int(len(co2_data) * 0.8)  # 80% for training, 20% for testing
train_data = co2_data[:train_size]
test_data = co2_data[train_size:]

# %%
# Train the model on the training set
best_model.fit(train_data.values[:-1], train_data.values[1:])
# Out:
# ARIMAWrapped(order=(0, 0, 1))

# %%
# Make predictions on the training and test sets
train_predictions = best_model.predict(train_data.values[:-1])
test_predictions = best_model.predict(test_data.values[:-1])

# %%
# Calculate MAE, MSE, and RMSE for training set
train_mae = mean_absolute_error(train_data.values[1:], train_predictions)
train_mse = mean_squared_error(train_data.values[1:], train_predictions)
train_rmse = np.sqrt(train_mse)
train_r2 = r2_score(train_data.values[1:], train_predictions)

# Calculate MAE, MSE, and RMSE for test set
test_mae = mean_absolute_error(test_data.values[1:], test_predictions)
test_mse = mean_squared_error(test_data.values[1:], test_predictions)
test_rmse = np.sqrt(test_mse)
test_r2 = r2_score(test_data.values[1:], test_predictions)

print("Training Phase:")
print("MAE:", train_mae)
print("MSE:", train_mse)
print("RMSE:", train_rmse)
print("R-squared:", train_r2)

print("\nTest Phase:")
print("MAE:", test_mae)
print("MSE:", test_mse)
print("RMSE:", test_rmse)
print("R-squared:", test_r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       3 train_mse = mean_squared_error(train_data.values[1:], train_predictions)
#       4 train_rmse = np.sqrt(train_mse)
# ----> 5 train_r2 = r2_score(train_data.values[1:], train_predictions)
#       7 # Calculate MAE, MSE, and RMSE for test set
#       8 test_mae = mean_absolute_error(test_data.values[1:], test_predictions)
#
# NameError: name 'r2_score' is not defined

# %%
Mean Squared Error (MSE): 203.8004405910339
Mean Absolute Error (MAE): 13.698965750056098
Root Mean Squared Error (RMSE): 14.275869171123484
